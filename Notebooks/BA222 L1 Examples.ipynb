# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pathlib

cur = pathlib.Path.cwd()

# %%
cereal_data = pd.read_excel(f'{cur.parent}/CSVs/BA222 L1 Examples.xlsx')

# %%
cereal_data.head()
# Out:
#                                 name manufacturer type  calories  protein
# 0               Mueslix Crispy Blend            K    C       160        3  \
# 1   Muesli Raisins; Dates; & Almonds            R    C       150        4
# 2  Muesli Raisins; Peaches; & Pecans            R    C       150        4
# 3             Just Right Fruit & Nut            K    C       140        3
# 4          Nutri-Grain Almond-Raisin            K    C       140        3
#
#    fat  sodium  fiber  carbs  sugars  potassium  weight  cups     rating
# 0    2     150    3.0   17.0      13        160    1.50  0.67  30.313351  \
# 1    3      95    3.0   16.0      11        170    1.00  1.00  37.136863
# 2    3     150    3.0   16.0      11        170    1.00  1.00  34.139765
# 3    1     170    2.0   20.0       9         95    1.30  0.75  36.471512
# 4    2     220    3.0   21.0       7        130    1.33  0.67  40.692320
#
#    Carbs2ofThis1Cheerios
# 0                   51.0
# 1                    NaN
# ...
